# %%
params = {
    "key": "33d28a024ade6c377ded6e2b3b69bcd4",
    "targetDt": "20251207"
}


import requests

url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json"


# API 요청
response = requests.get(url, params=params)
# 결과 출력
if response.status_code == 200:

    print(response.json())
else:
    print(f"Error: {response.status_code}")

print(response.json()["boxOfficeResult"]['dailyBoxOfficeList'][0]['movieNm'])

data = response.json()
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스', 'showRange': '20251207~20251207', 'dailyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20252432', 'movieNm': '주토피아 2', 'openDt': '2025-11-26', 'salesAmt': '4857713890', 'salesShare': '71.2', 'salesInten': '-673692790', 'salesChange': '-12.2', 'salesAcc': '37828596080', 'audiCnt': '499220', 'audiInten': '-64524', 'audiChange': '-11.4', 'audiAcc': '3931448', 'scrnCnt': '2240', 'showCnt': '9920'}, {'rnum': '2', 'rank': '2', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20249326', 'movieNm': '윗집 사람들', 'openDt': '2025-12-03', 'salesAmt': '502969900', 'salesShare': '7.4', 'salesInten': '9768090', 'salesChange': '2', 'salesAcc': '1784717430', 'audiCnt': '50929', 'audiInten': '749', 'audiChange': '1.5', 'audiAcc': '185843', 'scrnCnt': '730', 'showCnt': '1527'}, {'rnum': '3', 'rank': '3', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20258739', 'movieNm': '극장판 주술회전: 시부야사변 X 사멸회유', 'openDt': '2025-12-03', 'salesAmt': '451306400', 'salesShare': '6.6', 'salesInten': '-104721390', 'salesChange': '-18.8', 'salesAcc': '2065523010', 'audiCnt': '42744', 'audiInten': '-10461', 'audiChange': '-19.7', 'audiAcc': '199484', 'scrnCnt': '728', 'showCnt': '1705'}, {'rnum': '4', 'rank': '4', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20253906', 'movieNm': '프레디의 피자가게 2', 'openDt': '2025-12-03', 'salesAmt': '241708230', 'salesShare': '3.5', 'salesInten': '-45147590', 'salesChange': '-15.7', 'salesAcc': '852436910', 'audiCnt': '24546', 'audiInten': '-4301', 'audiChange': '-14.9', 'audiAcc': '86136', 'scrnCnt': '523', 'showCnt': '857'}, {'rnum': '5', 'rank': '5', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20255381', 'movieNm': '위키드: 포 굿', 'openDt': '2025-11-19', 'salesAmt': '185034110', 'salesShare': '2.7', 'salesInten': '-32680900', 'salesChange': '-15', 'salesAcc': '8943009820', 'audiCnt': '18501', 'audiInten': '-2920', 'audiChange': '-13.6', 'audiAcc': '871053', 'scrnCnt': '458', 'showCnt': '645'}, {'rnum': '6', 'rank': '6', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20233259', 'movieNm': '정보원', 'openDt': '2025-12-03', 'salesAmt': '157554630', 'salesShare': '2.3', 'salesInten': '-29769380', 'salesChange': '-15.9', 'salesAcc': '945448010', 'audiCnt': '16721', 'audiInten': '-3059', 'audiChange': '-15.5', 'audiAcc': '101458', 'scrnCnt': '651', 'showCnt': '1164'}, {'rnum': '7', 'rank': '7', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20258383', 'movieNm': '나우 유 씨 미 3', 'openDt': '2025-11-12', 'salesAmt': '94955400', 'salesShare': '1.4', 'salesInten': '-20555420', 'salesChange': '-17.8', 'salesAcc': '12563710670', 'audiCnt': '9576', 'audiInten': '-1905', 'audiChange': '-16.6', 'audiAcc': '1326700', 'scrnCnt': '387', 'showCnt': '521'}, {'rnum': '8', 'rank': '8', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20256757', 'movieNm': '극장판 체인소 맨: 레제편', 'openDt': '2025-09-24', 'salesAmt': '62890520', 'salesShare': '0.9', 'salesInten': '-87899600', 'salesChange': '-58.3', 'salesAcc': '35673580360', 'audiCnt': '6144', 'audiInten': '-8342', 'audiChange': '-57.6', 'audiAcc': '3393427', 'scrnCnt': '221', 'showCnt': '251'}, {'rnum': '9', 'rank': '9', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20257161', 'movieNm': '국보', 'openDt': '2025-11-19', 'salesAmt': '45777560', 'salesShare': '0.7', 'salesInten': '-75460', 'salesChange': '-0.2', 'salesAcc': '1359853850', 'audiCnt': '4577', 'audiInten': '62', 'audiChange': '1.4', 'audiAcc': '143954', 'scrnCnt': '164', 'showCnt': '178'}, {'rnum': '10', 'rank': '10', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20259618', 'movieNm': '콘크리트 마켓', 'openDt': '2025-12-03', 'salesAmt': '37594500', 'salesShare': '0.6', 'salesInten': '-16181800', 'salesChange': '-30.1', 'salesAcc': '167189600', 'audiCnt': '3470', 'audiInten': '-1628', 'audiChange': '-31.9', 'audiAcc': '19042', 'scrnCnt': '191', 'showCnt': '253'}]}}
# 주토피아 2

# %%
if bool(data) is True:
    items = data['boxOfficeResult']['dailyBoxOfficeList']

if bool(items) is True:
    print(items)
# Out:
# [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20252432', 'movieNm': '주토피아 2', 'openDt': '2025-11-26', 'salesAmt': '4857713890', 'salesShare': '71.2', 'salesInten': '-673692790', 'salesChange': '-12.2', 'salesAcc': '37828596080', 'audiCnt': '499220', 'audiInten': '-64524', 'audiChange': '-11.4', 'audiAcc': '3931448', 'scrnCnt': '2240', 'showCnt': '9920'}, {'rnum': '2', 'rank': '2', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20249326', 'movieNm': '윗집 사람들', 'openDt': '2025-12-03', 'salesAmt': '502969900', 'salesShare': '7.4', 'salesInten': '9768090', 'salesChange': '2', 'salesAcc': '1784717430', 'audiCnt': '50929', 'audiInten': '749', 'audiChange': '1.5', 'audiAcc': '185843', 'scrnCnt': '730', 'showCnt': '1527'}, {'rnum': '3', 'rank': '3', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20258739', 'movieNm': '극장판 주술회전: 시부야사변 X 사멸회유', 'openDt': '2025-12-03', 'salesAmt': '451306400', 'salesShare': '6.6', 'salesInten': '-104721390', 'salesChange': '-18.8', 'salesAcc': '2065523010', 'audiCnt': '42744', 'audiInten': '-10461', 'audiChange': '-19.7', 'audiAcc': '199484', 'scrnCnt': '728', 'showCnt': '1705'}, {'rnum': '4', 'rank': '4', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20253906', 'movieNm': '프레디의 피자가게 2', 'openDt': '2025-12-03', 'salesAmt': '241708230', 'salesShare': '3.5', 'salesInten': '-45147590', 'salesChange': '-15.7', 'salesAcc': '852436910', 'audiCnt': '24546', 'audiInten': '-4301', 'audiChange': '-14.9', 'audiAcc': '86136', 'scrnCnt': '523', 'showCnt': '857'}, {'rnum': '5', 'rank': '5', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20255381', 'movieNm': '위키드: 포 굿', 'openDt': '2025-11-19', 'salesAmt': '185034110', 'salesShare': '2.7', 'salesInten': '-32680900', 'salesChange': '-15', 'salesAcc': '8943009820', 'audiCnt': '18501', 'audiInten': '-2920', 'audiChange': '-13.6', 'audiAcc': '871053', 'scrnCnt': '458', 'showCnt': '645'}, {'rnum': '6', 'rank': '6', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20233259', 'movieNm': '정보원', 'openDt': '2025-12-03', 'salesAmt': '157554630', 'salesShare': '2.3', 'salesInten': '-29769380', 'salesChange': '-15.9', 'salesAcc': '945448010', 'audiCnt': '16721', 'audiInten': '-3059', 'audiChange': '-15.5', 'audiAcc': '101458', 'scrnCnt': '651', 'showCnt': '1164'}, {'rnum': '7', 'rank': '7', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20258383', 'movieNm': '나우 유 씨 미 3', 'openDt': '2025-11-12', 'salesAmt': '94955400', 'salesShare': '1.4', 'salesInten': '-20555420', 'salesChange': '-17.8', 'salesAcc': '12563710670', 'audiCnt': '9576', 'audiInten': '-1905', 'audiChange': '-16.6', 'audiAcc': '1326700', 'scrnCnt': '387', 'showCnt': '521'}, {'rnum': '8', 'rank': '8', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20256757', 'movieNm': '극장판 체인소 맨: 레제편', 'openDt': '2025-09-24', 'salesAmt': '62890520', 'salesShare': '0.9', 'salesInten': '-87899600', 'salesChange': '-58.3', 'salesAcc': '35673580360', 'audiCnt': '6144', 'audiInten': '-8342', 'audiChange': '-57.6', 'audiAcc': '3393427', 'scrnCnt': '221', 'showCnt': '251'}, {'rnum': '9', 'rank': '9', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20257161', 'movieNm': '국보', 'openDt': '2025-11-19', 'salesAmt': '45777560', 'salesShare': '0.7', 'salesInten': '-75460', 'salesChange': '-0.2', 'salesAcc': '1359853850', 'audiCnt': '4577', 'audiInten': '62', 'audiChange': '1.4', 'audiAcc': '143954', 'scrnCnt': '164', 'showCnt': '178'}, {'rnum': '10', 'rank': '10', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20259618', 'movieNm': '콘크리트 마켓', 'openDt': '2025-12-03', 'salesAmt': '37594500', 'salesShare': '0.6', 'salesInten': '-16181800', 'salesChange': '-30.1', 'salesAcc': '167189600', 'audiCnt': '3470', 'audiInten': '-1628', 'audiChange': '-31.9', 'audiAcc': '19042', 'scrnCnt': '191', 'showCnt': '253'}]

# %%
import csv

with open('movie_data.csv', 'w', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['순위', '영화이름', '개봉일자'])  # 헤더 작성

    for item in items:
        writer.writerow([item['rank'], item['movieNm'], item['openDt']])

# %%
try:
    response = requests.get(url, params=params)
    response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")

# %%
import pandas as pd

df = pd.read_csv('movie_data.csv')
df.dropna(inplace=True)  # 결측치 제거
df['개봉일자'] = pd.to_datetime(df['개봉일자'])

# %%
df.to_csv('final_data.csv', index=False) #csv
